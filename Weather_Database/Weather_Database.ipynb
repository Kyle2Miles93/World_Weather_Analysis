# %%
# import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime 
from config_copy import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city from each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 790

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters.
record_count = 1
set_count = 1

# loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create end-point URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # print the URL record, set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information in the city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        continue
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | rezina
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | pryazha
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | luhyny
# Processing Record 8 of Set 1 | hobyo
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | vostok
# Processing Record 14 of Set 1 | porto walter
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | rawson
# Processing Record 17 of Set 1 | elko
# Processing Record 18 of Set 1 | lugoba
# Processing Record 19 of Set 1 | saint-augustin
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | tecpan
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | fort nelson
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | baglung
# Processing Record 27 of Set 1 | saint-pierre
# Processing Record 28 of Set 1 | stornoway
# Processing Record 29 of Set 1 | santa fe
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | kangaatsiaq
# Processing Record 41 of Set 1 | maunabo
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 1 | maryville
# Processing Record 45 of Set 1 | alta floresta
# Processing Record 46 of Set 1 | moerai
# Processing Record 47 of Set 1 | marienburg
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 2 | sansai
# City not found. Skipping...
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | avera
# Processing Record 5 of Set 2 | havoysund
# Processing Record 6 of Set 2 | svetlogorsk
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | prince rupert
# Processing Record 10 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | mingaora
# Processing Record 14 of Set 2 | ruyigi
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | barabash
# Processing Record 17 of Set 2 | wanning
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | coahuayana
# Processing Record 21 of Set 2 | shimanovsk
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | ngunguru
# Processing Record 26 of Set 2 | senador canedo
# Processing Record 27 of Set 2 | isiro
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | nioro
# Processing Record 30 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 2 | manzhouli
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | shache
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | coihaique
# Processing Record 37 of Set 2 | tarquinia
# Processing Record 38 of Set 2 | lixourion
# Processing Record 39 of Set 2 | caravelas
# Processing Record 40 of Set 2 | semporna
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | umm lajj
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | qurayyat
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | raymond terrace
# Processing Record 4 of Set 3 | pevek
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | glendive
# Processing Record 7 of Set 3 | iwanai
# Processing Record 8 of Set 3 | solnechnyy
# Processing Record 9 of Set 3 | kristiansund
# Processing Record 10 of Set 3 | mataura
# Processing Record 11 of Set 3 | itako
# Processing Record 12 of Set 3 | carutapera
# Processing Record 13 of Set 3 | surt
# Processing Record 14 of Set 3 | maniitsoq
# Processing Record 15 of Set 3 | hofn
# Processing Record 16 of Set 3 | zhaodong
# Processing Record 17 of Set 3 | port hardy
# Processing Record 18 of Set 3 | eyemouth
# Processing Record 19 of Set 3 | dawlatabad
# Processing Record 20 of Set 3 | rocha
# Processing Record 21 of Set 3 | chapais
# Processing Record 22 of Set 3 | severo-kurilsk
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | marsa matruh
# Processing Record 25 of Set 3 | leshukonskoye
# Processing Record 26 of Set 3 | buritizeiro
# Processing Record 27 of Set 3 | lashio
# Processing Record 28 of Set 3 | atuona
# Processing Record 29 of Set 3 | umm jarr
# City not found. Skipping...
# Processing Record 30 of Set 3 | shakhrinau
# City not found. Skipping...
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | fortuna
# Processing Record 33 of Set 3 | hami
# Processing Record 34 of Set 3 | whitehorse
# Processing Record 35 of Set 3 | nanortalik
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | mvuma
# Processing Record 38 of Set 3 | nancha
# Processing Record 39 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 3 | mount gambier
# Processing Record 41 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 3 | ravar
# Processing Record 43 of Set 3 | davila
# Processing Record 44 of Set 3 | anamur
# Processing Record 45 of Set 3 | odienne
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | hornepayne
# Processing Record 49 of Set 3 | bathsheba
# Processing Record 50 of Set 3 | agadir
# Processing Record 1 of Set 4 | orlik
# Processing Record 2 of Set 4 | pangnirtung
# Processing Record 3 of Set 4 | viedma
# Processing Record 4 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | fortuna foothills
# Processing Record 7 of Set 4 | srednekolymsk
# Processing Record 8 of Set 4 | kalabo
# Processing Record 9 of Set 4 | novyy oskol
# Processing Record 10 of Set 4 | jiujiang
# Processing Record 11 of Set 4 | abbeville
# Processing Record 12 of Set 4 | grindavik
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | ntoum
# Processing Record 15 of Set 4 | sao joao da barra
# Processing Record 16 of Set 4 | trat
# Processing Record 17 of Set 4 | xingyi
# Processing Record 18 of Set 4 | tombouctou
# Processing Record 19 of Set 4 | fairbanks
# Processing Record 20 of Set 4 | altay
# Processing Record 21 of Set 4 | mecca
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | adre
# Processing Record 24 of Set 4 | sao filipe
# Processing Record 25 of Set 4 | berezovyy
# Processing Record 26 of Set 4 | oak ridge
# Processing Record 27 of Set 4 | mukhen
# Processing Record 28 of Set 4 | flin flon
# Processing Record 29 of Set 4 | cayenne
# Processing Record 30 of Set 4 | port blair
# Processing Record 31 of Set 4 | alofi
# Processing Record 32 of Set 4 | makokou
# Processing Record 33 of Set 4 | port lincoln
# Processing Record 34 of Set 4 | esperance
# Processing Record 35 of Set 4 | kutum
# Processing Record 36 of Set 4 | vila franca do campo
# Processing Record 37 of Set 4 | meulaboh
# Processing Record 38 of Set 4 | vestmanna
# Processing Record 39 of Set 4 | novi ligure
# Processing Record 40 of Set 4 | mazabuka
# Processing Record 41 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 42 of Set 4 | dubti
# Processing Record 43 of Set 4 | valle de allende
# Processing Record 44 of Set 4 | ngara
# Processing Record 45 of Set 4 | iracoubo
# Processing Record 46 of Set 4 | linhares
# Processing Record 47 of Set 4 | korop
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | kalghatgi
# Processing Record 50 of Set 4 | la ronge
# Processing Record 1 of Set 5 | todos santos
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | myrtle beach
# Processing Record 4 of Set 5 | kahului
# Processing Record 5 of Set 5 | ingham
# Processing Record 6 of Set 5 | namatanai
# Processing Record 7 of Set 5 | verkhnyaya inta
# Processing Record 8 of Set 5 | miracema do tocantins
# Processing Record 9 of Set 5 | cherskiy
# Processing Record 10 of Set 5 | zhezkazgan
# Processing Record 11 of Set 5 | bellevue
# Processing Record 12 of Set 5 | bulgan
# Processing Record 13 of Set 5 | bundaberg
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | newport
# Processing Record 16 of Set 5 | esna
# Processing Record 17 of Set 5 | baykit
# Processing Record 18 of Set 5 | bartica
# Processing Record 19 of Set 5 | zalantun
# Processing Record 20 of Set 5 | taltal
# Processing Record 21 of Set 5 | duz
# City not found. Skipping...
# Processing Record 22 of Set 5 | alwar
# Processing Record 23 of Set 5 | grand gaube
# Processing Record 24 of Set 5 | cockburn town
# Processing Record 25 of Set 5 | ratnagiri
# Processing Record 26 of Set 5 | karratha
# Processing Record 27 of Set 5 | acapulco
# Processing Record 28 of Set 5 | teguldet
# Processing Record 29 of Set 5 | maimon
# City not found. Skipping...
# Processing Record 30 of Set 5 | kachiry
# Processing Record 31 of Set 5 | samarai
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | mehamn
# Processing Record 34 of Set 5 | tutoia
# Processing Record 35 of Set 5 | dongsheng
# Processing Record 36 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 37 of Set 5 | jedrzejow
# Processing Record 38 of Set 5 | nantucket
# Processing Record 39 of Set 5 | cravo norte
# Processing Record 40 of Set 5 | port elizabeth
# Processing Record 41 of Set 5 | ponta do sol
# Processing Record 42 of Set 5 | chulman
# Processing Record 43 of Set 5 | norfolk
# Processing Record 44 of Set 5 | halifax
# Processing Record 45 of Set 5 | skoghall
# Processing Record 46 of Set 5 | kargil
# Processing Record 47 of Set 5 | waipawa
# Processing Record 48 of Set 5 | karasburg
# Processing Record 49 of Set 5 | asfi
# Processing Record 50 of Set 5 | esmeraldas
# Processing Record 1 of Set 6 | charters towers
# Processing Record 2 of Set 6 | cap malheureux
# Processing Record 3 of Set 6 | te anau
# Processing Record 4 of Set 6 | pundaguitan
# Processing Record 5 of Set 6 | egvekinot
# Processing Record 6 of Set 6 | antalaha
# Processing Record 7 of Set 6 | north bend
# Processing Record 8 of Set 6 | deputatskiy
# Processing Record 9 of Set 6 | valdivia
# Processing Record 10 of Set 6 | araouane
# Processing Record 11 of Set 6 | aswan
# Processing Record 12 of Set 6 | iquitos
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | jerantut
# Processing Record 16 of Set 6 | havelock
# Processing Record 17 of Set 6 | angoche
# Processing Record 18 of Set 6 | carbonear
# Processing Record 19 of Set 6 | akyab
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | ulladulla
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | harsin
# Processing Record 25 of Set 6 | mindszent
# Processing Record 26 of Set 6 | jizan
# Processing Record 27 of Set 6 | poum
# Processing Record 28 of Set 6 | warri
# Processing Record 29 of Set 6 | djibo
# Processing Record 30 of Set 6 | isangel
# Processing Record 31 of Set 6 | khatanga
# Processing Record 32 of Set 6 | quatre cocos
# Processing Record 33 of Set 6 | nizwa
# Processing Record 34 of Set 6 | kondinskoye
# Processing Record 35 of Set 6 | chumikan
# Processing Record 36 of Set 6 | gouyave
# Processing Record 37 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 6 | carberry
# Processing Record 39 of Set 6 | candido mendes
# Processing Record 40 of Set 6 | sola
# Processing Record 41 of Set 6 | pirgos
# Processing Record 42 of Set 6 | kyaikkami
# Processing Record 43 of Set 6 | west wendover
# Processing Record 44 of Set 6 | iqaluit
# Processing Record 45 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 6 | alice springs
# Processing Record 47 of Set 6 | marfino
# Processing Record 48 of Set 6 | hampton
# Processing Record 49 of Set 6 | portree
# Processing Record 50 of Set 6 | labuhan
# Processing Record 1 of Set 7 | dunedin
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | udachnyy
# Processing Record 4 of Set 7 | quelimane
# Processing Record 5 of Set 7 | mahishadal
# Processing Record 6 of Set 7 | kapit
# Processing Record 7 of Set 7 | torbay
# Processing Record 8 of Set 7 | bay roberts
# Processing Record 9 of Set 7 | tuatapere
# Processing Record 10 of Set 7 | yunyang
# Processing Record 11 of Set 7 | luorong
# Processing Record 12 of Set 7 | ugoofaaru
# Processing Record 13 of Set 7 | samana
# Processing Record 14 of Set 7 | mackay
# Processing Record 15 of Set 7 | san cristobal
# Processing Record 16 of Set 7 | gravdal
# Processing Record 17 of Set 7 | clayton
# Processing Record 18 of Set 7 | mahendragarh
# Processing Record 19 of Set 7 | emba
# Processing Record 20 of Set 7 | tete
# Processing Record 21 of Set 7 | roma
# Processing Record 22 of Set 7 | neiafu
# Processing Record 23 of Set 7 | curuguaty
# Processing Record 24 of Set 7 | takaka
# Processing Record 25 of Set 7 | arman
# Processing Record 26 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 7 | mahebourg
# Processing Record 28 of Set 7 | ligayan
# Processing Record 29 of Set 7 | lagos
# Processing Record 30 of Set 7 | beni suef
# Processing Record 31 of Set 7 | urmston
# Processing Record 32 of Set 7 | swift current
# Processing Record 33 of Set 7 | codrington
# Processing Record 34 of Set 7 | providencia
# Processing Record 35 of Set 7 | morondava
# Processing Record 36 of Set 7 | ternate
# Processing Record 37 of Set 7 | nishihara
# Processing Record 38 of Set 7 | kavaratti
# Processing Record 39 of Set 7 | newcastle
# Processing Record 40 of Set 7 | kobryn
# Processing Record 41 of Set 7 | belmonte
# Processing Record 42 of Set 7 | khani
# Processing Record 43 of Set 7 | inhambane
# Processing Record 44 of Set 7 | anahuac
# Processing Record 45 of Set 7 | monteagudo
# Processing Record 46 of Set 7 | saint marys
# Processing Record 47 of Set 7 | richards bay
# Processing Record 48 of Set 7 | pisco
# Processing Record 49 of Set 7 | namibe
# Processing Record 50 of Set 7 | maldonado
# Processing Record 1 of Set 8 | acarau
# Processing Record 2 of Set 8 | basco
# Processing Record 3 of Set 8 | christiana
# Processing Record 4 of Set 8 | klaksvik
# Processing Record 5 of Set 8 | tokur
# Processing Record 6 of Set 8 | killam
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | constitucion
# Processing Record 9 of Set 8 | salinopolis
# Processing Record 10 of Set 8 | susanino
# Processing Record 11 of Set 8 | general pico
# Processing Record 12 of Set 8 | kodiak
# Processing Record 13 of Set 8 | makakilo city
# Processing Record 14 of Set 8 | mola di bari
# Processing Record 15 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 8 | vanavara
# Processing Record 17 of Set 8 | camacha
# Processing Record 18 of Set 8 | marsberg
# Processing Record 19 of Set 8 | san quintin
# Processing Record 20 of Set 8 | asau
# Processing Record 21 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 8 | ganzhou
# Processing Record 23 of Set 8 | north mankato
# Processing Record 24 of Set 8 | kushmurun
# Processing Record 25 of Set 8 | northam
# Processing Record 26 of Set 8 | turinskaya sloboda
# Processing Record 27 of Set 8 | lata
# Processing Record 28 of Set 8 | yumen
# Processing Record 29 of Set 8 | bakchar
# Processing Record 30 of Set 8 | jiangyou
# Processing Record 31 of Set 8 | ust-maya
# Processing Record 32 of Set 8 | hualmay
# Processing Record 33 of Set 8 | kanye
# Processing Record 34 of Set 8 | beloha
# Processing Record 35 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 8 | shingu
# Processing Record 38 of Set 8 | mizdah
# Processing Record 39 of Set 8 | ahuimanu
# Processing Record 40 of Set 8 | vestmannaeyjar
# Processing Record 41 of Set 8 | owando
# Processing Record 42 of Set 8 | morgan city
# Processing Record 43 of Set 8 | aklavik
# Processing Record 44 of Set 8 | biltine
# Processing Record 45 of Set 8 | kuching
# Processing Record 46 of Set 8 | burnie
# Processing Record 47 of Set 8 | lakewood
# Processing Record 48 of Set 8 | arriaga
# Processing Record 49 of Set 8 | sirjan
# Processing Record 50 of Set 8 | maragogi
# Processing Record 1 of Set 9 | soddy-daisy
# Processing Record 2 of Set 9 | sisimiut
# Processing Record 3 of Set 9 | byron bay
# Processing Record 4 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 9 | port moresby
# Processing Record 7 of Set 9 | mascota
# Processing Record 8 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 9 | qinhuangdao
# Processing Record 10 of Set 9 | souillac
# Processing Record 11 of Set 9 | teluk nibung
# Processing Record 12 of Set 9 | san policarpo
# Processing Record 13 of Set 9 | guerrero negro
# Processing Record 14 of Set 9 | aurillac
# Processing Record 15 of Set 9 | shubarshi
# Processing Record 16 of Set 9 | faanui
# Processing Record 17 of Set 9 | kaeo
# Processing Record 18 of Set 9 | baherden
# Processing Record 19 of Set 9 | yar-sale
# Processing Record 20 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 9 | kalmunai
# Processing Record 22 of Set 9 | rancho palos verdes
# Processing Record 23 of Set 9 | varna
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | dormidontovka
# Processing Record 26 of Set 9 | airai
# Processing Record 27 of Set 9 | adrar
# Processing Record 28 of Set 9 | key west
# Processing Record 29 of Set 9 | belaya gora
# Processing Record 30 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 9 | hervey bay
# Processing Record 32 of Set 9 | sambava
# Processing Record 33 of Set 9 | esmeralda
# Processing Record 34 of Set 9 | soe
# Processing Record 35 of Set 9 | dibrugarh
# Processing Record 36 of Set 9 | san ramon
# Processing Record 37 of Set 9 | punta cardon
# Processing Record 38 of Set 9 | chunoyar
# Processing Record 39 of Set 9 | lebowakgomo
# Processing Record 40 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 9 | mendoza
# Processing Record 42 of Set 9 | tonj
# Processing Record 43 of Set 9 | tuban
# Processing Record 44 of Set 9 | vardo
# Processing Record 45 of Set 9 | comodoro rivadavia
# Processing Record 46 of Set 9 | fukue
# Processing Record 47 of Set 9 | ixtapa
# Processing Record 48 of Set 9 | ostrovnoy
# Processing Record 49 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 9 | itanhem
# Processing Record 1 of Set 10 | puerto quijarro
# Processing Record 2 of Set 10 | brae
# Processing Record 3 of Set 10 | buluang
# Processing Record 4 of Set 10 | cimarron hills
# Processing Record 5 of Set 10 | leningradskiy
# Processing Record 6 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 7 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 10 | port hedland
# Processing Record 9 of Set 10 | muisne
# Processing Record 10 of Set 10 | pemberton
# Processing Record 11 of Set 10 | zhigansk
# Processing Record 12 of Set 10 | kajaani
# Processing Record 13 of Set 10 | aranos
# Processing Record 14 of Set 10 | college
# Processing Record 15 of Set 10 | koson
# Processing Record 16 of Set 10 | camargo
# Processing Record 17 of Set 10 | keti bandar
# Processing Record 18 of Set 10 | ahipara
# Processing Record 19 of Set 10 | lompoc
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | husavik
# Processing Record 22 of Set 10 | camana
# Processing Record 23 of Set 10 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 24 of Set 10 | son la
# Processing Record 25 of Set 10 | finschhafen
# Processing Record 26 of Set 10 | port macquarie
# Processing Record 27 of Set 10 | petatlan
# Processing Record 28 of Set 10 | sinop
# Processing Record 29 of Set 10 | buala
# Processing Record 30 of Set 10 | eyl
# Processing Record 31 of Set 10 | henties bay
# Processing Record 32 of Set 10 | palmer
# Processing Record 33 of Set 10 | gannan
# Processing Record 34 of Set 10 | russell
# Processing Record 35 of Set 10 | mitsamiouli
# Processing Record 36 of Set 10 | khomeynishahr
# City not found. Skipping...
# Processing Record 37 of Set 10 | atikokan
# Processing Record 38 of Set 10 | pokrovsk
# Processing Record 39 of Set 10 | lasa
# Processing Record 40 of Set 10 | guozhen
# Processing Record 41 of Set 10 | preston
# Processing Record 42 of Set 10 | angra dos reis
# Processing Record 43 of Set 10 | colares
# Processing Record 44 of Set 10 | lebanon
# Processing Record 45 of Set 10 | brandon
# Processing Record 46 of Set 10 | maroantsetra
# Processing Record 47 of Set 10 | aguachica
# Processing Record 48 of Set 10 | jaque
# Processing Record 49 of Set 10 | hirara
# Processing Record 50 of Set 10 | prieska
# Processing Record 1 of Set 11 | bani walid
# Processing Record 2 of Set 11 | noumea
# Processing Record 3 of Set 11 | coolum beach
# Processing Record 4 of Set 11 | boende
# Processing Record 5 of Set 11 | vidalia
# Processing Record 6 of Set 11 | raga
# Processing Record 7 of Set 11 | kostomuksha
# Processing Record 8 of Set 11 | mikhaylovka
# Processing Record 9 of Set 11 | douentza
# Processing Record 10 of Set 11 | haines junction
# Processing Record 11 of Set 11 | rangapara
# Processing Record 12 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 11 | kununurra
# Processing Record 14 of Set 11 | sibiti
# Processing Record 15 of Set 11 | nuuk
# Processing Record 16 of Set 11 | touros
# Processing Record 17 of Set 11 | isla vista
# Processing Record 18 of Set 11 | mangrol
# Processing Record 19 of Set 11 | leh
# Processing Record 20 of Set 11 | kushnarenkovo
# Processing Record 21 of Set 11 | harbour breton
# Processing Record 22 of Set 11 | la paz
# Processing Record 23 of Set 11 | shimoda
# Processing Record 24 of Set 11 | paamiut
# Processing Record 25 of Set 11 | hvide sande
# Processing Record 26 of Set 11 | half moon bay
# Processing Record 27 of Set 11 | dodge city
# Processing Record 28 of Set 11 | marquard
# Processing Record 29 of Set 11 | phan thiet
# Processing Record 30 of Set 11 | ullapool
# Processing Record 31 of Set 11 | sainte-thecle
# Processing Record 32 of Set 11 | uthal
# Processing Record 33 of Set 11 | cairns
# Processing Record 34 of Set 11 | cabedelo
# Processing Record 35 of Set 11 | calama
# Processing Record 36 of Set 11 | aktash
# Processing Record 37 of Set 11 | pierre
# Processing Record 38 of Set 11 | muros
# Processing Record 39 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 11 | bilibino
# Processing Record 41 of Set 11 | linjiang
# Processing Record 42 of Set 11 | san carlos de bariloche
# Processing Record 43 of Set 11 | malampaka
# Processing Record 44 of Set 11 | padang
# Processing Record 45 of Set 11 | muzhi
# Processing Record 46 of Set 11 | nosy varika
# Processing Record 47 of Set 11 | salym
# Processing Record 48 of Set 11 | haapu
# City not found. Skipping...
# Processing Record 49 of Set 11 | ferme-neuve
# Processing Record 50 of Set 11 | witu
# Processing Record 1 of Set 12 | vila velha
# Processing Record 2 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 12 | saldanha
# Processing Record 4 of Set 12 | rockport
# Processing Record 5 of Set 12 | yerbogachen
# Processing Record 6 of Set 12 | utica
# Processing Record 7 of Set 12 | chipurupalle
# Processing Record 8 of Set 12 | eyrarbakki
# Processing Record 9 of Set 12 | dzaoudzi
# Processing Record 10 of Set 12 | krasnoarmeysk
# Processing Record 11 of Set 12 | santa cruz del sur
# Processing Record 12 of Set 12 | naze
# Processing Record 13 of Set 12 | la libertad
# Processing Record 14 of Set 12 | riyadh
# Processing Record 15 of Set 12 | denpasar
# Processing Record 16 of Set 12 | pavlohrad
# Processing Record 17 of Set 12 | harwich
# Processing Record 18 of Set 12 | port-cartier
# Processing Record 19 of Set 12 | olafsvik
# Processing Record 20 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 21 of Set 12 | priiskovyy
# Processing Record 22 of Set 12 | taganak
# Processing Record 23 of Set 12 | cabo san lucas
# Processing Record 24 of Set 12 | okhotsk
# Processing Record 25 of Set 12 | nara
# Processing Record 26 of Set 12 | port-gentil
# Processing Record 27 of Set 12 | aktau
# Processing Record 28 of Set 12 | cap-aux-meules
# Processing Record 29 of Set 12 | margate
# Processing Record 30 of Set 12 | sao geraldo do araguaia
# Processing Record 31 of Set 12 | abu samrah
# Processing Record 32 of Set 12 | black diamond
# Processing Record 33 of Set 12 | bozeman
# Processing Record 34 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 12 | bandarbeyla
# Processing Record 36 of Set 12 | chipinge
# Processing Record 37 of Set 12 | amazar
# Processing Record 38 of Set 12 | bubaque
# Processing Record 39 of Set 12 | gasa
# Processing Record 40 of Set 12 | portland
# Processing Record 41 of Set 12 | tigil
# Processing Record 42 of Set 12 | synya
# Processing Record 43 of Set 12 | narsimhapur
# Processing Record 44 of Set 12 | puerto cabezas
# Processing Record 45 of Set 12 | pontianak
# Processing Record 46 of Set 12 | syedove
# Processing Record 47 of Set 12 | lamin
# Processing Record 48 of Set 12 | rovaniemi
# Processing Record 49 of Set 12 | juneau
# Processing Record 50 of Set 12 | uray
# Processing Record 1 of Set 13 | sakakah
# Processing Record 2 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 13 | flinders
# Processing Record 4 of Set 13 | abu dhabi
# Processing Record 5 of Set 13 | winneba
# Processing Record 6 of Set 13 | baruun-urt
# Processing Record 7 of Set 13 | lavrentiya
# Processing Record 8 of Set 13 | puerto madryn
# Processing Record 9 of Set 13 | satuba
# Processing Record 10 of Set 13 | carballo
# Processing Record 11 of Set 13 | elumalai
# Processing Record 12 of Set 13 | monterey
# Processing Record 13 of Set 13 | harer
# Processing Record 14 of Set 13 | mattru
# Processing Record 15 of Set 13 | qasigiannguit
# Processing Record 16 of Set 13 | terney
# Processing Record 17 of Set 13 | limbe
# Processing Record 18 of Set 13 | vao
# Processing Record 19 of Set 13 | vandra
# Processing Record 20 of Set 13 | mentougou
# Processing Record 21 of Set 13 | baghmara
# Processing Record 22 of Set 13 | tsabong
# Processing Record 23 of Set 13 | yining
# Processing Record 24 of Set 13 | shebunino
# Processing Record 25 of Set 13 | thinadhoo
# Processing Record 26 of Set 13 | atambua
# Processing Record 27 of Set 13 | zeya
# Processing Record 28 of Set 13 | kloulklubed
# Processing Record 29 of Set 13 | tual
# Processing Record 30 of Set 13 | ojinaga
# Processing Record 31 of Set 13 | bafilo
# Processing Record 32 of Set 13 | yinchuan
# Processing Record 33 of Set 13 | burkhala
# City not found. Skipping...
# Processing Record 34 of Set 13 | ouro preto do oeste
# Processing Record 35 of Set 13 | lorengau
# Processing Record 36 of Set 13 | nabire
# Processing Record 37 of Set 13 | estrella
# Processing Record 38 of Set 13 | erenhot
# Processing Record 39 of Set 13 | veraval
# Processing Record 40 of Set 13 | antofagasta
# Processing Record 41 of Set 13 | beaverlodge
# Processing Record 42 of Set 13 | bastrop
# Processing Record 43 of Set 13 | tiznit
# Processing Record 44 of Set 13 | coronado
# Processing Record 45 of Set 13 | huarmey
# Processing Record 46 of Set 13 | la fleche
# Processing Record 47 of Set 13 | omboue
# Processing Record 48 of Set 13 | ballina
# Processing Record 49 of Set 13 | zhigalovo
# Processing Record 50 of Set 13 | chuy
# Processing Record 1 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 14 | komsomolskiy
# Processing Record 3 of Set 14 | nokaneng
# Processing Record 4 of Set 14 | malpe
# Processing Record 5 of Set 14 | general roca
# Processing Record 6 of Set 14 | los lunas
# Processing Record 7 of Set 14 | ruwi
# Processing Record 8 of Set 14 | taoudenni
# Processing Record 9 of Set 14 | suez
# Processing Record 10 of Set 14 | keita
# Processing Record 11 of Set 14 | kovur
# Processing Record 12 of Set 14 | kuryk
# Processing Record 13 of Set 14 | zyryanka
# Processing Record 14 of Set 14 | lima
# Processing Record 15 of Set 14 | sinjar
# Processing Record 16 of Set 14 | fare
# Processing Record 17 of Set 14 | warrnambool
# Processing Record 18 of Set 14 | hereford
# Processing Record 19 of Set 14 | tres picos
# Processing Record 20 of Set 14 | atar
# Processing Record 21 of Set 14 | skiros
# City not found. Skipping...
# Processing Record 22 of Set 14 | pilao arcado
# City not found. Skipping...
# Processing Record 23 of Set 14 | kaminskiy
# Processing Record 24 of Set 14 | xining
# Processing Record 25 of Set 14 | chegem
# Processing Record 26 of Set 14 | amli
# Processing Record 27 of Set 14 | saint-francois
# Processing Record 28 of Set 14 | sarahan
# Processing Record 29 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 14 | linchuan
# City not found. Skipping...
# Processing Record 31 of Set 14 | san fernando
# Processing Record 32 of Set 14 | xuddur
# Processing Record 33 of Set 14 | muscat
# Processing Record 34 of Set 14 | diffa
# Processing Record 35 of Set 14 | shangrao
# Processing Record 36 of Set 14 | qaqortoq
# Processing Record 37 of Set 14 | tautira
# Processing Record 38 of Set 14 | nome
# Processing Record 39 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 14 | itarema
# Processing Record 41 of Set 14 | teya
# Processing Record 42 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 14 | blois
# Processing Record 44 of Set 14 | muroto
# Processing Record 45 of Set 14 | nhulunbuy
# Processing Record 46 of Set 14 | ifanadiana
# Processing Record 47 of Set 14 | ambon
# Processing Record 48 of Set 14 | payo
# Processing Record 49 of Set 14 | kokopo
# Processing Record 50 of Set 14 | camocim
# Processing Record 1 of Set 15 | luanda
# Processing Record 2 of Set 15 | lazaro cardenas
# Processing Record 3 of Set 15 | islamabad
# Processing Record 4 of Set 15 | faya
# Processing Record 5 of Set 15 | balan
# Processing Record 6 of Set 15 | shishou
# Processing Record 7 of Set 15 | treinta y tres
# Processing Record 8 of Set 15 | baculin
# Processing Record 9 of Set 15 | yenagoa
# Processing Record 10 of Set 15 | yulara
# Processing Record 11 of Set 15 | linxia
# Processing Record 12 of Set 15 | laguna
# Processing Record 13 of Set 15 | manggar
# Processing Record 14 of Set 15 | sibolga
# Processing Record 15 of Set 15 | bonavista
# Processing Record 16 of Set 15 | gimli
# Processing Record 17 of Set 15 | hannibal
# Processing Record 18 of Set 15 | hauterive
# Processing Record 19 of Set 15 | santa rosa
# Processing Record 20 of Set 15 | barhi
# Processing Record 21 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 15 | parabel
# Processing Record 23 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 15 | magdagachi
# Processing Record 25 of Set 15 | nacala
# Processing Record 26 of Set 15 | neyshabur
# Processing Record 27 of Set 15 | ballstad
# City not found. Skipping...
# Processing Record 28 of Set 15 | palana
# Processing Record 29 of Set 15 | turayf
# Processing Record 30 of Set 15 | borsad
# Processing Record 31 of Set 15 | surman
# Processing Record 32 of Set 15 | pochutla
# Processing Record 33 of Set 15 | inta
# Processing Record 34 of Set 15 | harper
# Processing Record 35 of Set 15 | enumclaw
# Processing Record 36 of Set 15 | san patricio
# Processing Record 37 of Set 15 | betsiamites
# Processing Record 38 of Set 15 | lieksa
# Processing Record 39 of Set 15 | matagami
# Processing Record 40 of Set 15 | inirida
# Processing Record 41 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 42 of Set 15 | walvis bay
# Processing Record 43 of Set 15 | mareeba
# Processing Record 44 of Set 15 | salto del guaira
# Processing Record 45 of Set 15 | vung tau
# Processing Record 46 of Set 15 | menongue
# Processing Record 47 of Set 15 | gat
# Processing Record 48 of Set 15 | camacari
# Processing Record 49 of Set 15 | papar
# Processing Record 50 of Set 15 | itoman
# Processing Record 1 of Set 16 | kurumkan
# Processing Record 2 of Set 16 | loma bonita
# Processing Record 3 of Set 16 | morgaushi
# Processing Record 4 of Set 16 | sao felix do xingu
# Processing Record 5 of Set 16 | buchanan
# Processing Record 6 of Set 16 | lagoa
# Processing Record 7 of Set 16 | banka
# Processing Record 8 of Set 16 | san juan de los morros
# Processing Record 9 of Set 16 | yeniseysk
# Processing Record 10 of Set 16 | lac du bonnet
# Processing Record 11 of Set 16 | pak phanang
# Processing Record 12 of Set 16 | itaituba
# Processing Record 13 of Set 16 | paracuru
# Processing Record 14 of Set 16 | gunjur
# Processing Record 15 of Set 16 | acajutla
# Processing Record 16 of Set 16 | progreso
# Processing Record 17 of Set 16 | druzhba
# Processing Record 18 of Set 16 | biak
# Processing Record 19 of Set 16 | kuybysheve
# Processing Record 20 of Set 16 | pacific grove
# Processing Record 21 of Set 16 | pringsewu
# Processing Record 22 of Set 16 | alekseyevsk
# Processing Record 23 of Set 16 | amahai
# Processing Record 24 of Set 16 | morden
# Processing Record 25 of Set 16 | san vicente
# Processing Record 26 of Set 16 | mogadishu
# Processing Record 27 of Set 16 | beira
# Processing Record 28 of Set 16 | texarkana
# Processing Record 29 of Set 16 | jasper
# Processing Record 30 of Set 16 | porto novo
# Processing Record 31 of Set 16 | kungurtug
# Processing Record 32 of Set 16 | sainte-maxime
# Processing Record 33 of Set 16 | carora
# Processing Record 34 of Set 16 | atherton
# Processing Record 35 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 16 | khasan
# Processing Record 37 of Set 16 | krasnyy chikoy
# Processing Record 38 of Set 16 | envira
# Processing Record 39 of Set 16 | vittoria
# Processing Record 40 of Set 16 | kommunisticheskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a new dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kapaa  22.0752 -159.3190     73.40        78          40
# 1        Rezina  47.7492   28.9622     32.47        92         100
# 2     Jamestown  42.0970  -79.2353     25.00        93          90
# 3        Albany  42.6001  -73.9662     26.01        75          17
# 4       Pryazha  61.6926   33.6216     15.80        92          90
# 5         Vaini -21.2000 -175.2000     82.40        83          75
# 6        Luhyny  51.0820   28.4006     32.14        95         100
# 7         Hobyo   5.3505   48.5268     77.22        62           8
# 8  Norman Wells  65.2820 -126.8329     -5.80        77           1
# 9     Carnarvon -24.8667  113.6333     91.40        55          24
#
#    Wind Speed Country                 Date Current Description
# 0        3.44      US  2021-01-08 05:34:58    scattered clouds
# 1        4.38      MD  2021-01-08 05:34:58     overcast clouds
# 2        5.75      US  2021-01-08 05:34:59     overcast clouds
# 3        6.13      US  2021-01-08 05:34:59          few clouds
# 4        4.47      RU  2021-01-08 05:34:59          light snow
# 5        5.75      TO  2021-01-08 05:34:59       broken clouds
# 6       13.27      UA  2021-01-08 05:35:00     overcast clouds
# 7       23.69      SO  2021-01-08 05:35:00           clear sky
# 8        4.61      CA  2021-01-08 05:35:00           clear sky
# 9       16.11      AU  2021-01-08 05:35:01          few clouds

# %%
city_data_df = city_data_df[["Date", "City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]

# %%
# Create ouput file.
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export file into CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
